# %%
from faker import Faker
import random
import pandas as pd
from datetime import datetime

# %%
# from faker import Faker
# import random

# Define the Zomato Data Generator class

class ZomatoDataGenerator:
    def __init__(self):
        self.fake = Faker()

    def create_customers(self, num_customers):
        customers = []
        for _ in range(num_customers):
            customers.append({
                "customer_id": _ + 1,
                "name": self.fake.name(),
                "email": self.fake.email(),
                "phone": self.fake.phone_number(),
                "address": self.fake.address(),
                "signup_date": self.fake.date_this_decade(),
                "is_premium": random.choice([True, False]),
                "preferred_cuisine": random.choice(['Indian', 'Chinese', 'Italian', 'Mexican', 'Japanese']),
                "total_orders": random.randint(1, 100),
                "average_rating": round(random.uniform(1, 5), 1)})
        return pd.DataFrame(customers)
    def create_restaurants(self, num_restaurants):
        cuisines = ["Indian", "Chinese", "Italian", "Mexican", "Japanese", "Thai"]
        restaurants = []
        for _ in range(num_restaurants):
            restaurants.append({
                "restaurant_id": _ + 1,
                "name": self.fake.company(),
                "cuisine_type": random.choice(['Indian', 'Chinese', 'Italian', 'Mexican', 'Japanese']),
                "location": self.fake.city(),
                "owner_name": self.fake.name(),
                "average_delivery_time": random.randint(20, 60),
                "contact_number": self.fake.phone_number(),
                "rating": round(random.uniform(1, 5), 1),
                "total_orders": random.randint(50, 100),
                "is_active": random.choice([True, False])})
        return pd.DataFrame(restaurants)
    def create_orders(self, num_orders):
        order_statuses = ["Pending", "Completed", "Cancelled"]
        orders = []
        for _ in range(num_orders):
            orders.append({
                "order_id": _ + 1,
                "customer_id": random.choice(['1001','2023', '9876']),
                "restaurant_id": random.choice(['1013', '5023', '7890']),
                "items": self.fake.sentence(nb_words=1),
                "quantity": random.randint(1, 5),
                "order_date": self.fake.date_this_year(),
                "delivery_time": self.fake.time(),
                "order_statuses": random.choice(['Pending', 'Delivered', 'Cancelled']),
                "total_amount": round(random.uniform(5.0, 100.0), 2),
                "payment_mode": random.choice(['Credit Card', 'Cash', 'UPI']),
                "discount_applied": round(random.uniform(0, 20), 2),
                "feedback_rating": round(random.uniform(1, 5), 1)})
        return pd.DataFrame(orders)
    def create_deliveries(self, num_deliveries):
        delivery_statuses = ["Delivered", "In Transit", "Failed"]
        deliveries = []
        for _ in range(num_deliveries):
            deliveries.append({
                "delivery_id": _ + 1,
                "order_id": random.choice(['1001', '2023', '9876']),
                "delivery_person_id": random.randint(1, 100),
                "delivery_status": random.choice(['On the way', 'Delivered']),
                "distance": round(random.uniform(1.0, 10.0), 2),
                "delivery_time": round(random.uniform(10, 60), 1),
                "estimated_time": random.randint(15, 30),
                "delivery_fee": round(random.uniform(2.0, 5.0), 2),
                "vehicle_type":random.choice(['Bike', 'Car', 'Scooter', 'Cycle'])})
        return pd.DataFrame(deliveries)

# %%
data = ZomatoDataGenerator()

A = data.create_customers(100)

# %%
A
# Out:
#     customer_id            name                        email  \
# 0             1  Jennifer Craig          eparker@example.org
# 1             2   Latoya Powell         miguel32@example.com
# 2             3       Mary Carr        lsullivan@example.com
# 3             4   Timothy Smith           mary58@example.com
# 4             5  Chelsey Landry   taylorcristina@example.net
# ..          ...             ...                          ...
# 95           96    Jordan Singh            hlane@example.net
# 96           97    Kelly Waters        weberjuan@example.net
# 97           98   Carol Jackson            gpham@example.org
# 98           99   Brandon Moore     kennethsmith@example.com
# 99          100   Ethan Mendoza  christopherware@example.com
#
#                      phone                                            address  \
# 0         437.511.9479x897  95920 Rodriguez Land Suite 352\nNew Tyler, CO ...
# 1   001-367-273-7872x65705  94280 Bell Trace Apt. 263\nAdamschester, GU 88177
# 2            (483)696-7594          409 Allen Parkway\nSmithborough, MS 29310
# 3             379.390.6468  2581 Matthew Burgs Suite 912\nCoopermouth, GA ...
# 4        (701)946-4439x061          7032 Samuel Flat\nNew Jasonview, NC 13264
# ..                     ...                                                ...
# 95        001-511-484-5015  2436 Charles Underpass Suite 113\nMatthewstown...
# 96       (469)336-8212x135   736 Hahn Cliffs Suite 229\nWest Brenda, NM 47013
# 97       412.488.9493x0156     476 Michelle Mountain\nNew Adamburgh, WV 51500
# 98      810-991-1449x81987                          USNS Taylor\nFPO AE 14210
# 99       491-847-4806x2075  4827 Martin Plain Apt. 999\nChristinefort, ID ...
#
#    signup_date  is_premium preferred_cuisine  total_orders  average_rating
# 0   2023-01-13       False           Italian            10             3.8
# 1   2020-09-26        True            Indian             9             3.2
# 2   2023-05-14        True           Chinese            35             4.6
# 3   2024-07-12        True           Chinese            87             1.2
# 4   2024-12-13       False           Mexican            28             2.6
# ..         ...         ...               ...           ...             ...
# 95  2022-06-16       False            Indian            86             2.5
# 96  2021-03-27       False          Japanese            95             3.7
# 97  2023-01-19        True           Mexican            12             4.8
# 98  2022-11-21       False           Italian             2             2.0
# 99  2022-05-15        True            Indian            62             4.9
#
# [100 rows x 10 columns]

# %%
B = data.create_restaurants(100)

# %%
B
# Out:
#     restaurant_id                           name cuisine_type  \
# 0               1                     Parker PLC     Japanese
# 1               2                       Mayo Ltd       Indian
# 2               3  Jones, Schneider and Holloway      Mexican
# 3               4                     Dean-Moore       Indian
# 4               5                      Jones PLC      Italian
# ..            ...                            ...          ...
# 95             96    Bishop, Armstrong and Duran     Japanese
# 96             97                   Young-Wright      Mexican
# 97             98                    Burgess PLC      Chinese
# 98             99               Anderson-Douglas      Mexican
# 99            100          Lewis, Moon and Smith      Chinese
#
#               location          owner_name  average_delivery_time  \
# 0           Aliciaview    Jennifer Shannon                     41
# 1          South James    Mr. Michael Diaz                     60
# 2         Lake Crystal        Jody Hubbard                     36
# 3         West Melissa         James Lewis                     41
# 4      North Debraport       Rebecca Lopez                     32
# ..                 ...                 ...                    ...
# 95     Christophertown      Sarah Williams                     50
# 96        Port Destiny       Michael Boyle                     27
# 97        Johnsonmouth       Shannon Hicks                     42
# 98  New Anthonychester  Mrs. Dawn Martinez                     34
# 99         South Laura          Tracy Kidd                     35
#
#           contact_number  rating  total_orders  is_active
# 0    (738)984-0192x69648     2.7            86      False
# 1      (708)650-1919x156     1.8            66      False
# 2          (386)783-9727     1.8            83       True
# 3       511-868-1492x470     3.0            94      False
# 4           780-876-2340     1.6            78      False
# ..                   ...     ...           ...        ...
# 95         (610)878-3633     3.2            74      False
# 96  001-496-954-9090x026     1.5            82       True
# 97            8939219380     4.1            76       True
# 98   (572)443-4842x21092     4.7            89      False
# 99      328-203-5773x768     2.6            52      False
#
# [100 rows x 10 columns]

# %%
C = data.create_orders(100)

# %%
C
# Out:
#     order_id customer_id restaurant_id     items  quantity  order_date  \
# 0          1        9876          5023  Central.         3  2025-01-15
# 1          2        9876          5023      Boy.         5  2025-01-02
# 2          3        9876          5023     Able.         1  2025-01-17
# 3          4        9876          7890  Million.         1  2025-01-14
# 4          5        1001          5023    Today.         2  2025-01-08
# ..       ...         ...           ...       ...       ...         ...
# 95        96        9876          7890     Into.         4  2025-01-03
# 96        97        2023          5023      Yes.         4  2025-01-17
# 97        98        1001          1013     Talk.         4  2025-01-07
# 98        99        2023          1013   Remain.         5  2025-01-02
# 99       100        9876          5023  Account.         1  2025-01-08
#
#    delivery_time order_statuses  total_amount payment_mode  discount_applied  \
# 0       12:24:47        Pending         80.15          UPI              5.47
# 1       16:52:10      Delivered         19.49         Cash              0.33
# 2       20:45:03      Delivered         28.70  Credit Card              1.68
# 3       20:54:55        Pending         81.19         Cash              7.48
# 4       17:13:45        Pending         67.96          UPI             12.64
# ..           ...            ...           ...          ...               ...
# 95      15:46:36      Cancelled         33.94         Cash              5.89
# 96      10:45:08      Cancelled         96.90         Cash             18.11
# 97      11:57:54      Cancelled         90.86         Cash             15.54
# 98      10:07:24        Pending         64.21         Cash             16.13
# 99      20:53:08      Cancelled         25.86          UPI              3.59
#
#     feedback_rating
# 0               3.0
# 1               3.8
# 2               4.2
# 3               1.7
# 4               1.3
# ..              ...
# 95              3.2
# 96              1.3
# 97              2.7
# 98              3.2
# 99              2.4
#
# [100 rows x 12 columns]

# %%
D = data.create_deliveries(100)

# %%
D
# Out:
#     delivery_id order_id  delivery_person_id delivery_status  distance  \
# 0             1     2023                  14      On the way      9.53
# 1             2     1001                  48       Delivered      6.72
# 2             3     1001                   3       Delivered      9.82
# 3             4     1001                  84      On the way      5.81
# 4             5     1001                  70       Delivered      9.86
# ..          ...      ...                 ...             ...       ...
# 95           96     2023                  15      On the way      8.06
# 96           97     2023                  62      On the way      2.08
# 97           98     2023                   1       Delivered      4.11
# 98           99     1001                  22      On the way      6.04
# 99          100     9876                  28      On the way      5.71
#
#     delivery_time  estimated_time  delivery_fee vehicle_type
# 0            22.1              27          4.70         Bike
# 1            55.5              23          3.53          Car
# 2            53.5              20          2.36          Car
# 3            10.8              29          3.34          Car
# 4            38.3              22          3.20         Bike
# ..            ...             ...           ...          ...
# 95           49.9              30          3.12          Car
# 96           31.7              15          3.85        Cycle
# 97           20.4              28          3.72         Bike
# 98           19.2              24          3.48        Cycle
# 99           43.5              26          4.33          Car
#
# [100 rows x 9 columns]

# %%
# Save each of the dataframes to CSV files
A. to_csv('customers.csv', index=False)
B. to_csv('restaurants.csv', index=False)
C. to_csv('orders.csv', index=False)
D. to_csv('deliveries.csv', index=False)

print("CSV files have been generated successfully.")
# Out:
# CSV files have been generated successfully.

# %%
import pymysql

# %%
con= pymysql.connect(
    host="localhost",
    user="root",
    password="123456789",
    autocommit=True
    )
print(con)
# Out:
# <pymysql.connections.Connection object at 0x0000026C738DAC90>

# %%
mycursor=con.cursor()
mycursor.execute("CREATE DATABASE ZOMATO_DB")
mycursor.execute("SHOW DATABASES")
for x in mycursor:
    print(x)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[3], line 2
#       1 mycursor=con.cursor()
# ----> 2 mycursor.execute("CREATE DATABASE ZOMATO_DB")
#       3 mycursor.execute("SHOW DATABASES")
#       4 for x in mycursor:
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# ProgrammingError: (1007, "Can't create database 'zomato_db'; database exists")

# %%
mycursor.execute("USE ZOMATO_DB")
# Out:
# 0

# %%
mycursor.execute("""
    CREATE TABLE customers (
        customer_id INT AUTO_INCREMENT PRIMARY KEY,
        name VARCHAR(255),
        phone VARCHAR(100),
        email VARCHAR(255),
        address VARCHAR(255),
        signup_date DATE,
        is_premium BOOLEAN,
        preferred_cuisine VARCHAR(100),
        total_orders INT,
        average_rating DECIMAL(5,1)
    )
""");
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mycursor.execute("""
#       2     CREATE TABLE customers (
#       3         customer_id INT AUTO_INCREMENT PRIMARY KEY,
#       4         name VARCHAR(255),
#       5         phone VARCHAR(100),
#       6         email VARCHAR(255),
#       7         address VARCHAR(255),
#       8         signup_date DATE,
#       9         is_premium BOOLEAN,
#      10         preferred_cuisine VARCHAR(100),
#      11         total_orders INT,
#      12         average_rating DECIMAL(5,1)
#      13     )
#      14 """);
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1050, "Table 'customers' already exists")

# %%
mycursor.execute("""
    CREATE TABLE restaurants (
        restaurant_id INT AUTO_INCREMENT PRIMARY KEY,
        name VARCHAR(255) NOT NULL,
        cuisine_type VARCHAR(100),
        location VARCHAR(255),
        owner_name VARCHAR(255),
        average_delivery_time INT, 
        contact_number VARCHAR(100),
        rating DECIMAL(2,1),       
        total_orders INT DEFAULT 0,
        is_active BOOLEAN DEFAULT TRUE
    )
""");
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 mycursor.execute("""
#       2     CREATE TABLE restaurants (
#       3         restaurant_id INT AUTO_INCREMENT PRIMARY KEY,
#       4         name VARCHAR(255) NOT NULL,
#       5         cuisine_type VARCHAR(100),
#       6         location VARCHAR(255),
#       7         owner_name VARCHAR(255),
#       8         average_delivery_time INT,
#       9         contact_number VARCHAR(100),
#      10         rating DECIMAL(2,1),
#      11         total_orders INT DEFAULT 0,
#      12         is_active BOOLEAN DEFAULT TRUE
#      13     )
#      14 """);
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1050, "Table 'restaurants' already exists")

# %%
mycursor.execute("""
    CREATE TABLE orders (
        order_id INT AUTO_INCREMENT PRIMARY KEY,
        customer_id INT,
        restaurant_id INT,
        items VARCHAR(255),
        quantity INT,
        order_date DATETIME,
        delivery_time TIME,
        order_statuses VARCHAR(100),
        total_amount DECIMAL(10,2),
        payment_mode VARCHAR(50),
        discount_applied DECIMAL(10,2),
        feedback_rating DECIMAL(2,1)
    )
""");
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 mycursor.execute("""
#       2     CREATE TABLE orders (
#       3         order_id INT AUTO_INCREMENT PRIMARY KEY,
#       4         customer_id INT,
#       5         restaurant_id INT,
#       6         items VARCHAR(255),
#       7         quantity INT,
#       8         order_date DATETIME,
#       9         delivery_time TIME,
#      10         order_statuses VARCHAR(100),
#      11         total_amount DECIMAL(10,2),
#      12         payment_mode VARCHAR(50),
#      13         discount_applied DECIMAL(10,2),
#      14         feedback_rating DECIMAL(2,1)
#      15     )
#      16 """);
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1050, "Table 'orders' already exists")

# %%
mycursor.execute("""
    CREATE TABLE deliveries (
        delivery_id INT AUTO_INCREMENT PRIMARY KEY,
        order_id INT NOT NULL,
        delivery_person_id INT,
        delivery_status VARCHAR(50),
        distance DECIMAL(5,2),             
        delivery_time INT,                 
        estimated_time INT,                
        delivery_fee DECIMAL(6,2),
        vehicle_type VARCHAR(50)        
    )
""");
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 mycursor.execute("""
#       2     CREATE TABLE deliveries (
#       3         delivery_id INT AUTO_INCREMENT PRIMARY KEY,
#       4         order_id INT NOT NULL,
#       5         delivery_person_id INT,
#       6         delivery_status VARCHAR(50),
#       7         distance DECIMAL(5,2),
#       8         delivery_time INT,
#       9         estimated_time INT,
#      10         delivery_fee DECIMAL(6,2),
#      11         vehicle_type VARCHAR(50)
#      12     )
#      13 """);
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\sarav\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1050, "Table 'deliveries' already exists")

# %%
# Read the CSV files into pandas dataframes

# %%
import pandas as pd

df1 = pd.read_csv('customers.csv')
df2 = pd.read_csv('restaurants.csv')
df3 = pd.read_csv('orders.csv')
df4 = pd.read_csv('deliveries.csv')
